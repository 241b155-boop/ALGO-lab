# %% [markdown]
# <a href="https://colab.research.google.com/github/241b155-boop/ALGO-lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
# user input graph

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    visited = []

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    paths = {}
    for node in graph:
        path = []
        current = node
        while current is not None:
            path.insert(0, current)
            current = previous[current]
        paths[node] = path

    return distances, paths


graph = {}
n = int(input("Enter number of nodes: "))

for i in range(n):
    node = input(f"Enter name of node {i+1}: ")
    graph[node] = {}

    edges = int(input(f"Enter number of edges from {node}: "))
    for j in range(edges):
        neighbor = input(f"  Enter neighbor {j+1} of {node}: ")
        weight = int(input(f"  Enter weight of edge {node} -> {neighbor}: "))
        graph[node][neighbor] = weight

source = input("Enter source node: ")
distances, paths = dijkstra(graph, source)

print(f"\nShortest paths from {source}:")
for node in graph:
    print(f"Path to {node}: {paths[node]} with distance {distances[node]}")
# Out:
# Enter number of nodes: 2
# Enter name of node 1: A
# Enter number of edges from A: 1
#   Enter neighbor 1 of A: B
#   Enter weight of edge A -> B: 2
# Enter name of node 2: B
# Enter number of edges from B: 1
#   Enter neighbor 1 of B: A
#   Enter weight of edge B -> A: 1
# Enter source node: A
#
# Shortest paths from A:
# Path to A: ['A'] with distance 0
# Path to B: ['A', 'B'] with distance 2

# %%
# SHORTEST PATH with total distance

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    visited = []

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    paths = {}
    for node in graph:
        path = []
        current = node
        while current is not None:
            path.insert(0, current)
            current = previous[current]
        paths[node] = path

    return distances, paths

graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10},
    'C': {'A': 2, 'B': 5, 'D': 3},
    'D': {'B': 10, 'C': 3}
}

distances, paths = dijkstra(graph, 'A')

for node in graph:
    print("Shortest path from A to", node, "=", paths[node], "with distance", distances[node])
# Out:
# Shortest path from A to A = ['A'] with distance 0
# Shortest path from A to B = ['A', 'B'] with distance 4
# Shortest path from A to C = ['A', 'C'] with distance 2
# Shortest path from A to D = ['A', 'C', 'D'] with distance 5

# %%
#CODE TO ADD 2 MORE NODES

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    visited = []

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    paths = {}
    for node in graph:
        path = []
        current = node
        while current is not None:
            path.insert(0, current)
            current = previous[current]
        paths[node] = path

    return distances, paths


graph = {}
n = int(input("Enter number of nodes: "))
for i in range(n):
    node = input(f"Enter name of node {i+1}: ")
    graph[node] = {}
    edges = int(input(f"Enter number of edges from {node}: "))
    for j in range(edges):
        neighbor = input(f"  Enter neighbor {j+1} of {node}: ")
        weight = int(input(f"  Enter weight of edge {node} -> {neighbor}: "))
        graph[node][neighbor] = weight

source = input("Enter source node: ")
distances, paths = dijkstra(graph, source)

for node in graph:
    print("Shortest path from", source, "to", node, "=", paths[node], "with distance", distances[node])
# Out:
# Enter number of nodes: 2
# Enter name of node 1: A
# Enter number of edges from A: 1
#   Enter neighbor 1 of A: B
#   Enter weight of edge A -> B: 1
# Enter name of node 2: B
# Enter number of edges from B: 1
#   Enter neighbor 1 of B: A
#   Enter weight of edge B -> A: 2
# Enter source node: A
# Shortest path from A to A = ['A'] with distance 0
# Shortest path from A to B = ['A', 'B'] with distance 1

# %%
# TESTING ALGORITHM FOR VARIOUS SOURCE NODES

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    visited = []

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    paths = {}
    for node in graph:
        path = []
        current = node
        while current is not None:
            path.insert(0, current)
            current = previous[current]
        paths[node] = path

    return distances, paths


graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10},
    'C': {'A': 2, 'B': 5, 'D': 3, 'E': 4},
    'D': {'B': 10, 'C': 3, 'F': 6},
    'E': {'C': 4, 'F': 1},
    'F': {'D': 6, 'E': 1}
}

for source in graph:
    distances, paths = dijkstra(graph, source)
    print(f"\nSource: {source}")
    for node in graph:
        print("Shortest path from", source, "to", node, "=", paths[node], "with distance", distances[node])
# Out:
# Source: A
# Shortest path from A to A = ['A'] with distance 0
# Shortest path from A to B = ['A', 'B'] with distance 4
# Shortest path from A to C = ['A', 'C'] with distance 2
# Shortest path from A to D = ['A', 'C', 'D'] with distance 5
# Shortest path from A to E = ['A', 'C', 'E'] with distance 6
# Shortest path from A to F = ['A', 'C', 'E', 'F'] with distance 7
#
# Source: B
# Shortest path from B to A = ['B', 'A'] with distance 4
# Shortest path from B to B = ['B'] with distance 0
# Shortest path from B to C = ['B', 'C'] with distance 5
# Shortest path from B to D = ['B', 'C', 'D'] with distance 8
# Shortest path from B to E = ['B', 'C', 'E'] with distance 9
# Shortest path from B to F = ['B', 'C', 'E', 'F'] with distance 10
#
# Source: C
# Shortest path from C to A = ['C', 'A'] with distance 2
# Shortest path from C to B = ['C', 'B'] with distance 5
# Shortest path from C to C = ['C'] with distance 0
# Shortest path from C to D = ['C', 'D'] with distance 3
# Shortest path from C to E = ['C', 'E'] with distance 4
# Shortest path from C to F = ['C', 'E', 'F'] with distance 5
#
# Source: D
# Shortest path from D to A = ['D', 'C', 'A'] with distance 5
# Shortest path from D to B = ['D', 'C', 'B'] with distance 8
# Shortest path from D to C = ['D', 'C'] with distance 3
# Shortest path from D to D = ['D'] with distance 0
# Shortest path from D to E = ['D', 'C', 'E'] with distance 7
# Shortest path from D to F = ['D', 'F'] with distance 6
#
# Source: E
# Shortest path from E to A = ['E', 'C', 'A'] with distance 6
# Shortest path from E to B = ['E', 'C', 'B'] with distance 9
# Shortest path from E to C = ['E', 'C'] with distance 4
# Shortest path from E to D = ['E', 'F', 'D'] with distance 7
# Shortest path from E to E = ['E'] with distance 0
# Shortest path from E to F = ['E', 'F'] with distance 1
#
# Source: F
# Shortest path from F to A = ['F', 'E', 'C', 'A'] with distance 7
# Shortest path from F to B = ['F', 'E', 'C', 'B'] with distance 10
# Shortest path from F to C = ['F', 'E', 'C'] with distance 5
# Shortest path from F to D = ['F', 'D'] with distance 6
# Shortest path from F to E = ['F', 'E'] with distance 1
# Shortest path from F to F = ['F'] with distance 0
